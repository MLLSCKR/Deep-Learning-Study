# %%
# %run mlp_model.ipynb
# %run dataset_redefine.ipynb

# %%
# abalone dataset(Regression)

ad = AbaloneDataset()
am = MlpModel('abalone_model', ad, [])
am.exec_all(epoch_count = 10, report = 2)
# Out:
# Model abalone_model train started:
#     Epoch 2 : cost = 8.191, accuracy = 0.733/0.711 (0/0 secs)
#     Epoch 4 : cost = 7.392, accuracy = 0.744/0.694 (0/0 secs)
#     Epoch 6 : cost = 7.247, accuracy = 0.747/0.737 (0/0 secs)
#     Epoch 8 : cost = 7.139, accuracy = 0.748/0.725 (0/0 secs)
#     Epoch 10 : cost = 7.054, accuracy = 0.751/0.746 (0/0 secs)
# Model abalone_model train ended in 0 secs
#     Model abalone_model test report : accuracy = 0.727, (0 secs)
#
# Model abalone_model visualization
# [0.00,0.00,1.00,0.70,0.53,0.17,1.56,0.61,0.39,0.44] => estimate 12.9 : answers 10.0
# [0.00,1.00,0.00,0.46,0.38,0.12,0.48,0.22,0.10,0.17] => estimate  8.7 : answers  7.0
# [0.00,0.00,1.00,0.58,0.45,0.14,1.14,0.56,0.22,0.29] => estimate 11.3 : answers  8.0

# %%
# pulsar dataset binary classification

pd = PulsarDataset()
pm = MlpModel('pulsar_model', pd, [4])
pm.exec_all()
# Out:
# Model pulsar_model train ended in 1 secs
#     Model pulsar_model test report : accuracy = 0.971, (0 secs)
#
# Model pulsar_model visualization
# [121.8, 48.0,  0.2,...] -> estimate star(probability : 0.01) : answer star -> 0
# [143.5, 46.0, -0.3,...] -> estimate star(probability : 0.00) : answer star -> 0
# [170.4, 40.9, -0.9,...] -> estimate star(probability : 0.01) : answer star -> 0

# %%
pm.visualize(5)
# Out:
# Model pulsar_model visualization
# [ 26.8, 27.4,  6.1,...] -> estimate pulsar(probability : 1.00) : answer pulsar -> 0
# [143.5, 40.5, -0.2,...] -> estimate star(probability : 0.00) : answer star -> 0
# [ 99.0, 44.0,  0.4,...] -> estimate star(probability : 0.02) : answer star -> 0
# [134.6, 50.6,  0.0,...] -> estimate star(probability : 0.00) : answer star -> 0
# [130.0, 53.9,  0.4,...] -> estimate star(probability : 0.17) : answer star -> 0

# %%
# Steel Dataset select.(multiple classification)

sd = SteelDataset()
sm = MlpModel('steel_model', sd, [12,7])
sm.exec_all(epoch_count = 50, report = 10)
# Out:
# Model steel_model train started:
#     Epoch 10 : cost = 0.790, accuracy = 0.352/0.299 (0/0 secs)
#     Epoch 20 : cost = 0.745, accuracy = 0.352/0.299 (0/0 secs)
#     Epoch 30 : cost = 0.719, accuracy = 0.352/0.299 (0/0 secs)
#     Epoch 40 : cost = 0.704, accuracy = 0.352/0.299 (1/1 secs)
#     Epoch 50 : cost = 0.694, accuracy = 0.352/0.299 (0/1 secs)
# Model steel_model train ended in 1 secs
#     Model steel_model test report : accuracy = 0.337, (0 secs)
#
# Model steel_model visualization
# estimated probability distribution [15,14,28,42] -> estimate : Stains : answer K_Scatch -> X
# estimated probability distribution [15,14,28,42] -> estimate : Stains : answer Z_Scratch -> X
# estimated probability distribution [15,14,28,42] -> estimate : Stains : answer Stains -> 0

# %%
# %run dataset_flowers.ipynb

# %%
fd = FlowersDataset()
fm = MlpModel('flowers_model_1', fd, [10])
fm.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2 : cost = 1.607, accuracy = 0.247/0.290 (3/3 secs)
#     Epoch 4 : cost = 1.605, accuracy = 0.247/0.260 (3/6 secs)
#     Epoch 6 : cost = 1.603, accuracy = 0.247/0.240 (4/10 secs)
#     Epoch 8 : cost = 1.602, accuracy = 0.247/0.290 (3/13 secs)
#     Epoch 10 : cost = 1.601, accuracy = 0.247/0.350 (4/17 secs)
# Model flowers_model_1 train ended in 17 secs
#     Model flowers_model_1 test report : accuracy = 0.222, (0 secs)
#
# Model flowers_model_1 visualization
# estimated probability distribution [19,22,19,18,21] -> estimate : dandelion : answer daisy -> X
# estimated probability distribution [19,22,19,18,21] -> estimate : dandelion : answer rose -> X
# estimated probability distribution [19,22,19,18,21] -> estimate : dandelion : answer tulip -> X
